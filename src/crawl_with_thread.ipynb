# %%
import requests
from bs4 import BeautifulSoup
import time
import os
from urllib.parse import urljoin, urlparse
import urllib3
import json
import threading 
import queue       
import logging

# %%
logging.basicConfig(level=logging.INFO,
                    format='%(asctime)s %(threadName)s: %(message)s',
                    datefmt='%Y-%m-%d %H:%M:%S')

urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

BASE_URL_UET = "https://www.vnu.edu.vn/home/?C1885"
ALLOWED_DOMAINS = ["uet.vnu.edu.vn", "vnu.edu.vn","ueb.edu.vn","hus.vnu.edu.vn","ussh.vnu.edu.vn","ulis.vnu.edu.vn","education.vnu.edu.vn","vju.ac.vn","is.vnu.edu.vn","hsb.edu.vn","law.vnu.edu.vn"]
DATA_DIR = "uet_vnu_data"
STATE_FILE = "crawl_state_2.json"
NUM_WORKER_THREADS = 8 

if not os.path.exists(DATA_DIR):
    os.makedirs(DATA_DIR)

# %%
work_queue = queue.Queue() 
visited_urls = set()
lock_visited_urls = threading.Lock() 
shutdown_event = threading.Event()   
urls_processed_count = 0             
lock_processed_count = threading.Lock()

# %%
def save_state(q_to_save, visited_to_save, filepath):
    logging.info(f"Đang lưu trạng thái vào {filepath}...")
    queue_items = []
    while not q_to_save.empty():
        try:
            queue_items.append(q_to_save.get_nowait())
        except queue.Empty:
            break

    state = {
        "queue": queue_items,
        "visited_urls": list(visited_to_save)
    }
    try:
        with open(filepath, 'w', encoding='utf-8') as f:
            json.dump(state, f, ensure_ascii=False, indent=4)
        logging.info(f"Đã lưu trạng thái: Queue={len(queue_items)}, Visited={len(visited_to_save)}")
    except Exception as e:
        logging.error(f"Lỗi khi lưu trạng thái: {e}")
    finally:
        for item in queue_items:
            q_to_save.put(item)


def load_state(filepath, q_to_load):
    global visited_urls 
    if os.path.exists(filepath):
        try:
            with open(filepath, 'r', encoding='utf-8') as f:
                state = json.load(f)
            
            while not q_to_load.empty():
                try: q_to_load.get_nowait()
                except queue.Empty: break

            loaded_queue_items = state.get("queue", [])
            for item in loaded_queue_items:
                q_to_load.put(item)
            
            visited_urls = set(state.get("visited_urls", []))
            logging.info(f"Đã tải trạng thái từ {filepath}: Queue={q_to_load.qsize()}, Visited={len(visited_urls)}")
            return True
        except Exception as e:
            logging.error(f"Lỗi khi tải trạng thái từ {filepath}: {e}. Bắt đầu với trạng thái mới.")
            visited_urls = set()
            return False
    else:
        logging.info("Không tìm thấy file trạng thái. Bắt đầu với trạng thái mới.")
        visited_urls = set()
        return False

def is_valid_url(url):
    parsed_url = urlparse(url)
    if parsed_url.scheme in ['http', 'https'] and parsed_url.netloc in ALLOWED_DOMAINS:
        return True
    return False

def sanitize_filename(url_str):
    filename = url_str.replace("http://", "").replace("https://", "").replace("/", "_").replace("?", "_").replace("=", "_").replace("&", "_").replace("%", "_")
    return "".join(c if c.isalnum() or c in ['_', '.'] else '_' for c in filename)[:150] + ".txt"

def save_content(url, content):
    try:
        filename = sanitize_filename(url)
        filepath = os.path.join(DATA_DIR, filename)
        with open(filepath, "w", encoding="utf-8") as f:
            f.write(content)
        logging.info(f"Đã lưu: {filepath}")
    except Exception as e:
        logging.error(f"Lỗi khi lưu file cho {url}: {e}")

# %%
def worker():
    global urls_processed_count 
    while not shutdown_event.is_set():
        try:
            current_url = work_queue.get(timeout=1) 
        except queue.Empty:
            continue 

        logging.info(f"Đang crawl: {current_url} (Queue: {work_queue.qsize()}, Visited: {len(visited_urls)})")
        
        try:
            headers = {'User-Agent': f'My Threaded UET Crawler ({threading.current_thread().name})'}
            response = requests.get(current_url, headers=headers, timeout=15, verify=False)
            response.raise_for_status()

            with lock_processed_count: 
                urls_processed_count +=1

            content_type = response.headers.get('Content-Type', '').lower()
            if 'text/html' in content_type:
                soup = BeautifulSoup(response.content, "html.parser")
                selectors = [
                    'article .entry-content', 'article .td-post-content', 'article .content',
                    '.noidung', '.content', '.entry-content', '.td-post-content', '.page-content',
                    'article', 'main', '#content',
                ]
                page_text_parts = []
                found_main_content = False
                for selector in selectors:
                    elements = soup.select(selector)
                    if elements:
                        for el in elements:
                            for unwanted_tag in el.select('nav, footer, script, style, .menu, .sidebar, .related-posts, .comments-area, .header, .site-header'):
                                unwanted_tag.decompose()
                            page_text_parts.append(el.get_text(separator="\n", strip=True))
                        found_main_content = True
                        break
                if not found_main_content and soup.body:
                    body_clone = BeautifulSoup(str(soup.body), "html.parser")
                    for unwanted_tag in body_clone.select('nav, footer, script, style, .menu, .sidebar, .header, .site-header'):
                        unwanted_tag.decompose()
                    page_text_parts.append(body_clone.get_text(separator="\n", strip=True))
                page_text = "\n\n".join(filter(None, page_text_parts))

                logging.info(f"Đang crawl: {current_url} (Queue: {work_queue.qsize()}, Visited: {len(visited_urls)})")
                
                for link_tag in soup.find_all('a', href=True):
                    href = link_tag['href'].strip()
                    if not href or href.startswith(('#', 'javascript:', 'mailto:')):
                        continue
                    
                    next_url = urljoin(current_url, href)
                    next_url_parsed = urlparse(next_url)
                    next_url_clean = next_url_parsed._replace(fragment="", query="").geturl()

                    excluded_extensions = ['.pdf', '.doc', '.docx', '.xls', '.xlsx', '.ppt', '.pptx',
                                           '.jpg', '.jpeg', '.png', '.gif', '.bmp', '.svg',
                                           '.zip', '.rar', '.tar.gz', '.mp3', '.mp4', '.avi']
                    if any(next_url_clean.lower().endswith(ext) for ext in excluded_extensions):
                        continue
                    
                    if is_valid_url(next_url_clean):
                        with lock_visited_urls: 
                            if next_url_clean not in visited_urls:
                                logging.debug(f"Thêm link mới vào queue: {next_url_clean}")
                                work_queue.put(next_url_clean)
                                
                with lock_visited_urls:
                    if current_url in visited_urls:
                        work_queue.task_done() 
                        continue 
                visited_urls.add(current_url)                

                if page_text.strip():
                    save_content(current_url, page_text)
                print(f"Đã lưu nội dung từ {current_url} vào file.")
            elif 'application/pdf' in content_type:
                logging.info(f"Tìm thấy file PDF: {current_url}. (Logic tải PDF chưa được triển khai)")
            else:
                logging.info(f"Bỏ qua nội dung không phải HTML/PDF: {content_type} tại {current_url}")

        except requests.exceptions.RequestException as e_req:
            logging.warning(f"Lỗi request với {current_url}: {e_req}")
        except Exception as e_proc:
            logging.error(f"Lỗi xử lý {current_url}: {e_proc}")
        finally:
            work_queue.task_done()

    logging.info(f"{threading.current_thread().name} is stopping.")

# %%
if not load_state(STATE_FILE, work_queue): 
    if work_queue.empty() and BASE_URL_UET not in visited_urls:
            work_queue.put(BASE_URL_UET)

threads = []
logging.info(f"Bắt đầu {NUM_WORKER_THREADS} worker threads...")
for i in range(NUM_WORKER_THREADS):
    thread = threading.Thread(target=worker, name=f"Worker-{i+1}")
    thread.daemon = True 
    threads.append(thread)
    thread.start()

try:
    while True:
        if work_queue.empty():
            all_tasks_done = True
            logging.info("Queue is empty. Checking if all workers are idle...")
            time.sleep(5) 
            if work_queue.empty():
                logging.info("Queue is still empty. Signaling workers to stop.")
                shutdown_event.set() 
                break 
        time.sleep(1) 

except KeyboardInterrupt:
    logging.info("\nĐã nhận tín hiệu dừng (Ctrl+C). Báo hiệu cho các worker dừng...")
    shutdown_event.set()
except Exception as e_main:
    logging.error(f"Lỗi nghiêm trọng trong main thread: {e_main}")
    shutdown_event.set()
finally:
    logging.info("Đợi các worker threads hoàn thành...")
    for thread in threads:
        thread.join(timeout=10) 
        if thread.is_alive():
            logging.warning(f"Thread {thread.name} vẫn còn chạy sau khi join timeout.")

    logging.info("Tất cả worker threads đã dừng (hoặc timeout).")
    save_state(work_queue, visited_urls, STATE_FILE)
    logging.info(f"Tổng số URL đã xử lý (ước tính): {urls_processed_count}")
    logging.info("Chương trình kết thúc.")
# Out:
# 2025-05-12 12:10:56 MainThread: Đã tải trạng thái từ crawl_state_2.json: Queue=64899, Visited=9722
# 2025-05-12 12:10:56 MainThread: Bắt đầu 8 worker threads...
# 2025-05-12 12:10:56 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/67 (Queue: 64898, Visited: 9722)
# 2025-05-12 12:10:56 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/68 (Queue: 64897, Visited: 9722)
# 2025-05-12 12:10:56 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/154/0 (Queue: 64896, Visited: 9722)
# 2025-05-12 12:10:56 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/index.php/WebControl/viewpage/190 (Queue: 64895, Visited: 9722)
# 2025-05-12 12:10:56 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/95 (Queue: 64894, Visited: 9722)
# 2025-05-12 12:10:56 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/185/0 (Queue: 64893, Visited: 9722)
# 2025-05-12 12:10:56 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/243 (Queue: 64892, Visited: 9722)
# 2025-05-12 12:10:56 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/283 (Queue: 64891, Visited: 9722)
# 2025-05-12 12:10:56 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/154/0 (Queue: 64891, Visited: 9722)
# 2025-05-12 12:10:56 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/185/0 (Queue: 64891, Visited: 9722)
# 2025-05-12 12:10:56 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/64 (Queue: 64904, Visited: 9722)
# 2025-05-12 12:10:56 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/95 (Queue: 64904, Visited: 9722)
# 2025-05-12 12:10:56 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/67 (Queue: 64913, Visited: 9722)
# 2025-05-12 12:10:56 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/index.php/WebControl/viewpage/190 (Queue: 64913, Visited: 9722)
# 2025-05-12 12:10:56 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/67 (Queue: 64913, Visited: 9722)
# 2025-05-12 12:10:57 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/243 (Queue: 64913, Visited: 9722)
# 2025-05-12 12:10:57 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/283 (Queue: 64913, Visited: 9722)
# 2025-05-12 12:10:57 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/68 (Queue: 64913, Visited: 9722)
# 2025-05-12 12:10:57 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/244 (Queue: 64914, Visited: 9722)
# 2025-05-12 12:10:57 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/72 (Queue: 64914, Visited: 9722)
# 2025-05-12 12:10:57 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/68 (Queue: 64914, Visited: 9722)
# 2025-05-12 12:10:57 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/75 (Queue: 64914, Visited: 9722)
# 2025-05-12 12:10:57 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/73 (Queue: 64914, Visited: 9722)
# 2025-05-12 12:10:57 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/74 (Queue: 64914, Visited: 9722)
# 2025-05-12 12:10:57 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/64 (Queue: 64914, Visited: 9722)
# 2025-05-12 12:10:57 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/329 (Queue: 64914, Visited: 9722)
# 2025-05-12 12:10:57 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/67 (Queue: 64914, Visited: 9722)
# 2025-05-12 12:10:57 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/76/0 (Queue: 64914, Visited: 9722)
# 2025-05-12 12:10:57 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/244 (Queue: 64914, Visited: 9722)
# 2025-05-12 12:10:58 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/Site/site/KSP/ (Queue: 64914, Visited: 9722)
# 2025-05-12 12:10:58 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/73 (Queue: 64914, Visited: 9722)
# 2025-05-12 12:10:58 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/76/0 (Queue: 64914, Visited: 9722)
# 2025-05-12 12:10:58 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/74 (Queue: 64914, Visited: 9722)
# 2025-05-12 12:10:58 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/72 (Queue: 64914, Visited: 9722)
# 2025-05-12 12:10:58 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/75 (Queue: 64914, Visited: 9722)
# 2025-05-12 12:10:58 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/Site/site/KCKHGD/ (Queue: 64914, Visited: 9722)
# 2025-05-12 12:10:58 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/Site/site/KQLGD/ (Queue: 64915, Visited: 9722)
# 2025-05-12 12:10:58 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/329 (Queue: 64915, Visited: 9722)
# 2025-05-12 12:10:58 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/153 (Queue: 64915, Visited: 9722)
# 2025-05-12 12:10:58 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/68 (Queue: 64915, Visited: 9722)
# 2025-05-12 12:10:58 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/Site/site/KCNGD/ (Queue: 64915, Visited: 9722)
# 2025-05-12 12:10:58 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/Site/site/KGDSTH/ (Queue: 64915, Visited: 9722)
# 2025-05-12 12:10:58 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/138 (Queue: 64915, Visited: 9722)
# 2025-05-12 12:10:58 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/83 (Queue: 64915, Visited: 9722)
# 2025-05-12 12:10:58 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/Site/site/KSP/ (Queue: 64915, Visited: 9722)
# 2025-05-12 12:10:58 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/208 (Queue: 64952, Visited: 9722)
# 2025-05-12 12:10:58 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/Site/site/KCKHGD/ (Queue: 64952, Visited: 9722)
# 2025-05-12 12:10:58 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/Site/site/KQLGD/ (Queue: 64952, Visited: 9722)
# 2025-05-12 12:10:58 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/246 (Queue: 64978, Visited: 9722)
# 2025-05-12 12:10:58 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/248 (Queue: 64992, Visited: 9722)
# 2025-05-12 12:10:58 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/Site/site/KGDSTH/ (Queue: 64992, Visited: 9722)
# 2025-05-12 12:10:58 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/247 (Queue: 65002, Visited: 9722)
# 2025-05-12 12:10:58 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/Site/site/KCNGD/ (Queue: 65002, Visited: 9722)
# 2025-05-12 12:10:58 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/196 (Queue: 65027, Visited: 9722)
# 2025-05-12 12:10:58 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/83 (Queue: 65027, Visited: 9722)
# 2025-05-12 12:10:58 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/13/0 (Queue: 65027, Visited: 9722)
# 2025-05-12 12:10:58 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/208 (Queue: 65027, Visited: 9722)
# 2025-05-12 12:10:59 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/52/0 (Queue: 65027, Visited: 9722)
# 2025-05-12 12:10:59 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/138 (Queue: 65027, Visited: 9722)
# 2025-05-12 12:10:59 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/153 (Queue: 65027, Visited: 9722)
# 2025-05-12 12:10:59 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/247 (Queue: 65027, Visited: 9722)
# 2025-05-12 12:10:59 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/246 (Queue: 65027, Visited: 9722)
# 2025-05-12 12:10:59 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/196 (Queue: 65027, Visited: 9722)
# 2025-05-12 12:10:59 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/53/0 (Queue: 65027, Visited: 9722)
# 2025-05-12 12:10:59 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/248 (Queue: 65027, Visited: 9722)
# 2025-05-12 12:10:59 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/284/0 (Queue: 65027, Visited: 9722)
# 2025-05-12 12:10:59 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/156/0 (Queue: 65027, Visited: 9722)
# 2025-05-12 12:10:59 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/171/0 (Queue: 65027, Visited: 9722)
# 2025-05-12 12:10:59 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/172/0 (Queue: 65027, Visited: 9722)
# 2025-05-12 12:10:59 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/173/0 (Queue: 65027, Visited: 9722)
# 2025-05-12 12:10:59 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/13/0 (Queue: 65027, Visited: 9722)
# 2025-05-12 12:10:59 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/52/0 (Queue: 65027, Visited: 9722)
# 2025-05-12 12:10:59 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/157/0 (Queue: 65031, Visited: 9722)
# 2025-05-12 12:10:59 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/159/0 (Queue: 65046, Visited: 9722)
# 2025-05-12 12:10:59 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/156/0 (Queue: 65046, Visited: 9722)
# 2025-05-12 12:10:59 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/164/0 (Queue: 65063, Visited: 9722)
# 2025-05-12 12:10:59 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/53/0 (Queue: 65063, Visited: 9722)
# 2025-05-12 12:11:00 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/160/0 (Queue: 65087, Visited: 9722)
# 2025-05-12 12:11:00 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/172/0 (Queue: 65087, Visited: 9722)
# 2025-05-12 12:11:00 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/235/0 (Queue: 65099, Visited: 9722)
# 2025-05-12 12:11:00 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/173/0 (Queue: 65099, Visited: 9722)
# 2025-05-12 12:11:00 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/284/0 (Queue: 65099, Visited: 9722)
# 2025-05-12 12:11:00 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/171/0 (Queue: 65099, Visited: 9722)
# 2025-05-12 12:11:00 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/162/0 (Queue: 65111, Visited: 9722)
# 2025-05-12 12:11:00 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/159/0 (Queue: 65111, Visited: 9722)
# 2025-05-12 12:11:00 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/157/0 (Queue: 65111, Visited: 9722)
# 2025-05-12 12:11:00 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/56/0 (Queue: 65120, Visited: 9722)
# 2025-05-12 12:11:00 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/164/0 (Queue: 65120, Visited: 9722)
# 2025-05-12 12:11:00 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/54/0 (Queue: 65134, Visited: 9722)
# 2025-05-12 12:11:00 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/161/0 (Queue: 65148, Visited: 9722)
# 2025-05-12 12:11:00 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/320/0 (Queue: 65165, Visited: 9722)
# 2025-05-12 12:11:00 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/175/0 (Queue: 65180, Visited: 9722)
# 2025-05-12 12:11:00 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/160/0 (Queue: 65180, Visited: 9722)
# 2025-05-12 12:11:00 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/15/0 (Queue: 65194, Visited: 9722)
# 2025-05-12 12:11:00 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/235/0 (Queue: 65194, Visited: 9722)
# 2025-05-12 12:11:00 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/16/0 (Queue: 65204, Visited: 9722)
# 2025-05-12 12:11:00 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/56/0 (Queue: 65204, Visited: 9722)
# 2025-05-12 12:11:00 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/215/0 (Queue: 65207, Visited: 9722)
# 2025-05-12 12:11:00 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/175/0 (Queue: 65207, Visited: 9722)
# 2025-05-12 12:11:01 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/320/0 (Queue: 65207, Visited: 9722)
# 2025-05-12 12:11:01 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/17/0 (Queue: 65218, Visited: 9722)
# 2025-05-12 12:11:01 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/161/0 (Queue: 65218, Visited: 9722)
# 2025-05-12 12:11:01 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/54/0 (Queue: 65218, Visited: 9722)
# 2025-05-12 12:11:01 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/207 (Queue: 65230, Visited: 9722)
# 2025-05-12 12:11:01 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/162/0 (Queue: 65230, Visited: 9722)
# 2025-05-12 12:11:01 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/188 (Queue: 65241, Visited: 9722)
# 2025-05-12 12:11:01 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/15/0 (Queue: 65241, Visited: 9722)
# 2025-05-12 12:11:01 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/16/0 (Queue: 65241, Visited: 9722)
# 2025-05-12 12:11:01 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/2/0 (Queue: 65254, Visited: 9722)
# 2025-05-12 12:11:01 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/249 (Queue: 65268, Visited: 9722)
# 2025-05-12 12:11:01 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/125/0 (Queue: 65287, Visited: 9722)
# 2025-05-12 12:11:01 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/19/0 (Queue: 65305, Visited: 9722)
# 2025-05-12 12:11:01 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/215/0 (Queue: 65305, Visited: 9722)
# 2025-05-12 12:11:01 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/21 (Queue: 65311, Visited: 9722)
# 2025-05-12 12:11:01 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/17/0 (Queue: 65311, Visited: 9722)
# 2025-05-12 12:11:01 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/22 (Queue: 65322, Visited: 9722)
# 2025-05-12 12:11:01 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/188 (Queue: 65322, Visited: 9722)
# 2025-05-12 12:11:01 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/207 (Queue: 65322, Visited: 9722)
# 2025-05-12 12:11:01 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/23 (Queue: 65322, Visited: 9722)
# 2025-05-12 12:11:01 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/19/0 (Queue: 65322, Visited: 9722)
# 2025-05-12 12:11:01 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/192 (Queue: 65324, Visited: 9722)
# 2025-05-12 12:11:01 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/24 (Queue: 65322, Visited: 9722)
# 2025-05-12 12:11:01 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/2/0 (Queue: 65322, Visited: 9722)
# 2025-05-12 12:11:01 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/125/0 (Queue: 65322, Visited: 9722)
# 2025-05-12 12:11:01 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/249 (Queue: 65322, Visited: 9722)
# 2025-05-12 12:11:02 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/22 (Queue: 65324, Visited: 9722)
# 2025-05-12 12:11:02 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/21 (Queue: 65324, Visited: 9722)
# 2025-05-12 12:11:02 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/25 (Queue: 65325, Visited: 9722)
# 2025-05-12 12:11:02 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/26 (Queue: 65345, Visited: 9722)
# 2025-05-12 12:11:02 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/205 (Queue: 65345, Visited: 9722)
# 2025-05-12 12:11:02 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/193 (Queue: 65345, Visited: 9722)
# 2025-05-12 12:11:02 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/195 (Queue: 65345, Visited: 9722)
# 2025-05-12 12:11:02 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/23 (Queue: 65345, Visited: 9722)
# 2025-05-12 12:11:02 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/183 (Queue: 65345, Visited: 9722)
# 2025-05-12 12:11:02 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/24 (Queue: 65345, Visited: 9722)
# 2025-05-12 12:11:02 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/192 (Queue: 65345, Visited: 9722)
# 2025-05-12 12:11:02 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/139 (Queue: 65345, Visited: 9722)
# 2025-05-12 12:11:02 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/26 (Queue: 65345, Visited: 9722)
# 2025-05-12 12:11:02 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/194 (Queue: 65345, Visited: 9722)
# 2025-05-12 12:11:02 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/205 (Queue: 65345, Visited: 9722)
# 2025-05-12 12:11:02 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/195 (Queue: 65345, Visited: 9722)
# 2025-05-12 12:11:02 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/193 (Queue: 65345, Visited: 9722)
# 2025-05-12 12:11:02 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/203 (Queue: 65345, Visited: 9722)
# 2025-05-12 12:11:02 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/25 (Queue: 65345, Visited: 9722)
# 2025-05-12 12:11:02 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/204 (Queue: 65345, Visited: 9722)
# 2025-05-12 12:11:02 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/183 (Queue: 65345, Visited: 9722)
# 2025-05-12 12:11:02 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/216 (Queue: 65345, Visited: 9722)
# 2025-05-12 12:11:02 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/318 (Queue: 65345, Visited: 9722)
# 2025-05-12 12:11:02 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/32/0 (Queue: 65345, Visited: 9722)
# 2025-05-12 12:11:02 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/166/0 (Queue: 65345, Visited: 9722)
# 2025-05-12 12:11:02 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/139 (Queue: 65345, Visited: 9722)
# 2025-05-12 12:11:02 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/201 (Queue: 65345, Visited: 9722)
# 2025-05-12 12:11:02 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/194 (Queue: 65345, Visited: 9722)
# 2025-05-12 12:11:02 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/33/0 (Queue: 65345, Visited: 9722)
# 2025-05-12 12:11:03 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/203 (Queue: 65345, Visited: 9722)
# 2025-05-12 12:11:03 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/32/0 (Queue: 65345, Visited: 9722)
# 2025-05-12 12:11:03 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/129 (Queue: 65345, Visited: 9722)
# 2025-05-12 12:11:03 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/216 (Queue: 65345, Visited: 9722)
# 2025-05-12 12:11:03 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/204 (Queue: 65345, Visited: 9722)
# 2025-05-12 12:11:03 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/318 (Queue: 65345, Visited: 9722)
# 2025-05-12 12:11:03 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/166/0 (Queue: 65345, Visited: 9722)
# 2025-05-12 12:11:03 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/130 (Queue: 65355, Visited: 9722)
# 2025-05-12 12:11:03 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/131 (Queue: 65355, Visited: 9722)
# 2025-05-12 12:11:03 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/201 (Queue: 65355, Visited: 9722)
# 2025-05-12 12:11:03 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/132 (Queue: 65355, Visited: 9722)
# 2025-05-12 12:11:03 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/33/0 (Queue: 65355, Visited: 9722)
# 2025-05-12 12:11:03 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/141 (Queue: 65355, Visited: 9722)
# 2025-05-12 12:11:03 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/142 (Queue: 65367, Visited: 9722)
# 2025-05-12 12:11:03 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/317 (Queue: 65367, Visited: 9722)
# 2025-05-12 12:11:03 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/322 (Queue: 65370, Visited: 9722)
# 2025-05-12 12:11:03 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/129 (Queue: 65370, Visited: 9722)
# 2025-05-12 12:11:03 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/328 (Queue: 65370, Visited: 9722)
# 2025-05-12 12:11:03 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/130 (Queue: 65370, Visited: 9722)
# 2025-05-12 12:11:03 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/46/0 (Queue: 65370, Visited: 9722)
# 2025-05-12 12:11:03 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/322 (Queue: 65370, Visited: 9722)
# 2025-05-12 12:11:04 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/141 (Queue: 65370, Visited: 9722)
# 2025-05-12 12:11:04 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/202 (Queue: 65370, Visited: 9722)
# 2025-05-12 12:11:04 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/131 (Queue: 65370, Visited: 9722)
# 2025-05-12 12:11:04 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/142 (Queue: 65370, Visited: 9722)
# 2025-05-12 12:11:04 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/317 (Queue: 65370, Visited: 9722)
# 2025-05-12 12:11:04 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/132 (Queue: 65370, Visited: 9722)
# 2025-05-12 12:11:04 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/250/0 (Queue: 65370, Visited: 9722)
# 2025-05-12 12:11:04 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/328 (Queue: 65370, Visited: 9722)
# 2025-05-12 12:11:04 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/133 (Queue: 65370, Visited: 9722)
# 2025-05-12 12:11:04 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/134 (Queue: 65371, Visited: 9722)
# 2025-05-12 12:11:04 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/135 (Queue: 65370, Visited: 9722)
# 2025-05-12 12:11:04 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/46/0 (Queue: 65370, Visited: 9722)
# 2025-05-12 12:11:04 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/206 (Queue: 65370, Visited: 9722)
# 2025-05-12 12:11:04 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/47/0 (Queue: 65370, Visited: 9722)
# 2025-05-12 12:11:04 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/304 (Queue: 65382, Visited: 9722)
# 2025-05-12 12:11:04 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/202 (Queue: 65382, Visited: 9722)
# 2025-05-12 12:11:04 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/292/0 (Queue: 65382, Visited: 9722)
# 2025-05-12 12:11:04 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/250/0 (Queue: 65382, Visited: 9722)
# 2025-05-12 12:11:04 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/293 (Queue: 65383, Visited: 9722)
# 2025-05-12 12:11:04 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/206 (Queue: 65383, Visited: 9722)
# 2025-05-12 12:11:04 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/294 (Queue: 65383, Visited: 9722)
# 2025-05-12 12:11:05 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/304 (Queue: 65383, Visited: 9722)
# 2025-05-12 12:11:05 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/47/0 (Queue: 65383, Visited: 9722)
# 2025-05-12 12:11:05 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/134 (Queue: 65383, Visited: 9722)
# 2025-05-12 12:11:05 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/133 (Queue: 65383, Visited: 9722)
# 2025-05-12 12:11:05 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/295 (Queue: 65383, Visited: 9722)
# 2025-05-12 12:11:05 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/292/0 (Queue: 65383, Visited: 9722)
# 2025-05-12 12:11:05 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/135 (Queue: 65383, Visited: 9722)
# 2025-05-12 12:11:05 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/123 (Queue: 65398, Visited: 9722)
# 2025-05-12 12:11:05 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/297 (Queue: 65397, Visited: 9722)
# 2025-05-12 12:11:05 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/299 (Queue: 65397, Visited: 9722)
# 2025-05-12 12:11:05 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/298 (Queue: 65398, Visited: 9722)
# 2025-05-12 12:11:05 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/296 (Queue: 65397, Visited: 9722)
# 2025-05-12 12:11:05 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/293 (Queue: 65398, Visited: 9722)
# 2025-05-12 12:11:05 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/124 (Queue: 65398, Visited: 9722)
# 2025-05-12 12:11:05 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/294 (Queue: 65398, Visited: 9722)
# 2025-05-12 12:11:05 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/191 (Queue: 65398, Visited: 9722)
# 2025-05-12 12:11:05 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/123 (Queue: 65398, Visited: 9722)
# 2025-05-12 12:11:06 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/124 (Queue: 65398, Visited: 9722)
# 2025-05-12 12:11:06 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/126 (Queue: 65398, Visited: 9722)
# 2025-05-12 12:11:06 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/295 (Queue: 65398, Visited: 9722)
# 2025-05-12 12:11:06 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/300/0 (Queue: 65398, Visited: 9722)
# 2025-05-12 12:11:06 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/299 (Queue: 65398, Visited: 9722)
# 2025-05-12 12:11:06 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/212/0 (Queue: 65398, Visited: 9722)
# 2025-05-12 12:11:06 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/191 (Queue: 65398, Visited: 9722)
# 2025-05-12 12:11:06 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/297 (Queue: 65398, Visited: 9722)
# 2025-05-12 12:11:06 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/296 (Queue: 65398, Visited: 9722)
# 2025-05-12 12:11:06 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/301/0 (Queue: 65398, Visited: 9722)
# 2025-05-12 12:11:06 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/214 (Queue: 65398, Visited: 9722)
# 2025-05-12 12:11:06 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/315 (Queue: 65398, Visited: 9722)
# 2025-05-12 12:11:06 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/9 (Queue: 65398, Visited: 9722)
# 2025-05-12 12:11:06 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/298 (Queue: 65398, Visited: 9722)
# 2025-05-12 12:11:06 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/252 (Queue: 65398, Visited: 9722)
# 2025-05-12 12:11:07 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/300/0 (Queue: 65398, Visited: 9722)
# 2025-05-12 12:11:07 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/253/0 (Queue: 65399, Visited: 9722)
# 2025-05-12 12:11:07 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/126 (Queue: 65399, Visited: 9722)
# 2025-05-12 12:11:07 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/212/0 (Queue: 65399, Visited: 9722)
# 2025-05-12 12:11:07 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/301/0 (Queue: 65399, Visited: 9722)
# 2025-05-12 12:11:07 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/104/0 (Queue: 65399, Visited: 9722)
# 2025-05-12 12:11:07 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/9 (Queue: 65399, Visited: 9722)
# 2025-05-12 12:11:07 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/315 (Queue: 65399, Visited: 9722)
# 2025-05-12 12:11:07 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/252 (Queue: 65399, Visited: 9722)
# 2025-05-12 12:11:07 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/254 (Queue: 65408, Visited: 9722)
# 2025-05-12 12:11:07 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/214 (Queue: 65408, Visited: 9722)
# 2025-05-12 12:11:07 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/256 (Queue: 65411, Visited: 9722)
# 2025-05-12 12:11:07 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/280 (Queue: 65411, Visited: 9722)
# 2025-05-12 12:11:07 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/259 (Queue: 65411, Visited: 9722)
# 2025-05-12 12:11:07 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/281 (Queue: 65411, Visited: 9722)
# 2025-05-12 12:11:07 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/176 (Queue: 65411, Visited: 9722)
# 2025-05-12 12:11:07 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/253/0 (Queue: 65411, Visited: 9722)
# 2025-05-12 12:11:07 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/257 (Queue: 65424, Visited: 9722)
# 2025-05-12 12:11:07 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/254 (Queue: 65424, Visited: 9722)
# 2025-05-12 12:11:07 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/106 (Queue: 65424, Visited: 9722)
# 2025-05-12 12:11:07 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/104/0 (Queue: 65424, Visited: 9722)
# 2025-05-12 12:11:08 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/280 (Queue: 65424, Visited: 9722)
# 2025-05-12 12:11:08 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/220 (Queue: 65429, Visited: 9722)
# 2025-05-12 12:11:08 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/281 (Queue: 65429, Visited: 9722)
# 2025-05-12 12:11:08 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/177 (Queue: 65429, Visited: 9722)
# 2025-05-12 12:11:08 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/176 (Queue: 65429, Visited: 9722)
# 2025-05-12 12:11:08 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/259 (Queue: 65429, Visited: 9722)
# 2025-05-12 12:11:08 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/181/0 (Queue: 65429, Visited: 9722)
# 2025-05-12 12:11:08 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/178 (Queue: 65429, Visited: 9722)
# 2025-05-12 12:11:08 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/179 (Queue: 65429, Visited: 9722)
# 2025-05-12 12:11:08 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/256 (Queue: 65429, Visited: 9722)
# 2025-05-12 12:11:08 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/180/0 (Queue: 65429, Visited: 9722)
# 2025-05-12 12:11:08 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/106 (Queue: 65429, Visited: 9722)
# 2025-05-12 12:11:08 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/182/0 (Queue: 65429, Visited: 9722)
# 2025-05-12 12:11:08 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/220 (Queue: 65429, Visited: 9722)
# 2025-05-12 12:11:08 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/177 (Queue: 65429, Visited: 9722)
# 2025-05-12 12:11:08 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/319 (Queue: 65429, Visited: 9722)
# 2025-05-12 12:11:08 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/179 (Queue: 65429, Visited: 9722)
# 2025-05-12 12:11:08 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/181/0 (Queue: 65429, Visited: 9722)
# 2025-05-12 12:11:09 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/105/0 (Queue: 65429, Visited: 9722)
# 2025-05-12 12:11:09 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/178 (Queue: 65429, Visited: 9722)
# 2025-05-12 12:11:09 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/180/0 (Queue: 65429, Visited: 9722)
# 2025-05-12 12:11:09 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/262/0 (Queue: 65429, Visited: 9722)
# 2025-05-12 12:11:09 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/182/0 (Queue: 65429, Visited: 9722)
# 2025-05-12 12:11:09 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/154/0 (Queue: 65432, Visited: 9722)
# 2025-05-12 12:11:09 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/276 (Queue: 65432, Visited: 9722)
# 2025-05-12 12:11:09 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/119/0 (Queue: 65439, Visited: 9722)
# 2025-05-12 12:11:09 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/233 (Queue: 65440, Visited: 9722)
# 2025-05-12 12:11:09 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/105/0 (Queue: 65440, Visited: 9722)
# 2025-05-12 12:11:09 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/226 (Queue: 65451, Visited: 9722)
# 2025-05-12 12:11:10 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/319 (Queue: 65451, Visited: 9722)
# 2025-05-12 12:11:10 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/262/0 (Queue: 65451, Visited: 9722)
# 2025-05-12 12:11:10 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/257 (Queue: 65451, Visited: 9722)
# 2025-05-12 12:11:10 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/227 (Queue: 65458, Visited: 9722)
# 2025-05-12 12:11:10 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/228/0 (Queue: 65469, Visited: 9722)
# 2025-05-12 12:11:10 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/119/0 (Queue: 65469, Visited: 9722)
# 2025-05-12 12:11:10 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/231 (Queue: 65469, Visited: 9722)
# 2025-05-12 12:11:10 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/276 (Queue: 65469, Visited: 9722)
# 2025-05-12 12:11:10 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/233 (Queue: 65469, Visited: 9722)
# 2025-05-12 12:11:10 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/154/0 (Queue: 65469, Visited: 9722)
# 2025-05-12 12:11:10 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/232/0 (Queue: 65482, Visited: 9722)
# 2025-05-12 12:11:10 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/229 (Queue: 65482, Visited: 9722)
# 2025-05-12 12:11:10 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/11 (Queue: 65483, Visited: 9722)
# 2025-05-12 12:11:10 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/266 (Queue: 65496, Visited: 9722)
# 2025-05-12 12:11:10 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/226 (Queue: 65496, Visited: 9722)
# 2025-05-12 12:11:10 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/279/0 (Queue: 65496, Visited: 9722)
# 2025-05-12 12:11:11 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/228/0 (Queue: 65496, Visited: 9722)
# 2025-05-12 12:11:11 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/88 (Queue: 65508, Visited: 9722)
# 2025-05-12 12:11:11 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/227 (Queue: 65508, Visited: 9722)
# 2025-05-12 12:11:11 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/263 (Queue: 65508, Visited: 9722)
# 2025-05-12 12:11:11 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/11 (Queue: 65508, Visited: 9722)
# 2025-05-12 12:11:11 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/232/0 (Queue: 65508, Visited: 9722)
# 2025-05-12 12:11:11 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/264 (Queue: 65508, Visited: 9722)
# 2025-05-12 12:11:11 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/265 (Queue: 65520, Visited: 9722)
# 2025-05-12 12:11:11 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/229 (Queue: 65520, Visited: 9722)
# 2025-05-12 12:11:11 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/266 (Queue: 65520, Visited: 9722)
# 2025-05-12 12:11:11 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/231 (Queue: 65520, Visited: 9722)
# 2025-05-12 12:11:11 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/279/0 (Queue: 65520, Visited: 9722)
# 2025-05-12 12:11:11 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/267 (Queue: 65520, Visited: 9722)
# 2025-05-12 12:11:11 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/269 (Queue: 65520, Visited: 9722)
# 2025-05-12 12:11:11 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/268 (Queue: 65520, Visited: 9722)
# 2025-05-12 12:11:11 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/88 (Queue: 65520, Visited: 9722)
# 2025-05-12 12:11:11 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/270 (Queue: 65531, Visited: 9722)
# 2025-05-12 12:11:11 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/263 (Queue: 65531, Visited: 9722)
# 2025-05-12 12:11:11 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/271 (Queue: 65531, Visited: 9722)
# 2025-05-12 12:11:11 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/89 (Queue: 65531, Visited: 9722)
# 2025-05-12 12:11:12 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/264 (Queue: 65531, Visited: 9722)
# 2025-05-12 12:11:12 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/272 (Queue: 65531, Visited: 9722)
# 2025-05-12 12:11:12 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/265 (Queue: 65531, Visited: 9722)
# 2025-05-12 12:11:12 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/273 (Queue: 65531, Visited: 9722)
# 2025-05-12 12:11:12 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/269 (Queue: 65531, Visited: 9722)
# 2025-05-12 12:11:12 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/267 (Queue: 65531, Visited: 9722)
# 2025-05-12 12:11:12 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/274 (Queue: 65531, Visited: 9722)
# 2025-05-12 12:11:12 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/268 (Queue: 65531, Visited: 9722)
# 2025-05-12 12:11:12 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/271 (Queue: 65531, Visited: 9722)
# 2025-05-12 12:11:12 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/275/0 (Queue: 65531, Visited: 9722)
# 2025-05-12 12:11:12 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/270 (Queue: 65531, Visited: 9722)
# 2025-05-12 12:11:12 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/89 (Queue: 65531, Visited: 9722)
# 2025-05-12 12:11:12 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/302/0 (Queue: 65531, Visited: 9722)
# 2025-05-12 12:11:12 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/272 (Queue: 65531, Visited: 9722)
# 2025-05-12 12:11:12 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/278 (Queue: 65531, Visited: 9722)
# 2025-05-12 12:11:12 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/150/0 (Queue: 65531, Visited: 9722)
# 2025-05-12 12:11:12 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/148/0 (Queue: 65531, Visited: 9722)
# 2025-05-12 12:11:12 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/213 (Queue: 65531, Visited: 9722)
# 2025-05-12 12:11:12 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/273 (Queue: 65531, Visited: 9722)
# 2025-05-12 12:11:12 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/221/0 (Queue: 65531, Visited: 9722)
# 2025-05-12 12:11:13 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/275/0 (Queue: 65531, Visited: 9722)
# 2025-05-12 12:11:13 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/278 (Queue: 65531, Visited: 9722)
# 2025-05-12 12:11:13 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/302/0 (Queue: 65531, Visited: 9722)
# 2025-05-12 12:11:13 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/213 (Queue: 65543, Visited: 9722)
# 2025-05-12 12:11:13 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/170/0 (Queue: 65543, Visited: 9722)
# 2025-05-12 12:11:13 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/198 (Queue: 65543, Visited: 9722)
# 2025-05-12 12:11:13 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/221/0 (Queue: 65543, Visited: 9722)
# 2025-05-12 12:11:13 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/190 (Queue: 65554, Visited: 9722)
# 2025-05-12 12:11:13 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/148/0 (Queue: 65554, Visited: 9722)
# 2025-05-12 12:11:13 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/150/0 (Queue: 65554, Visited: 9722)
# 2025-05-12 12:11:13 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/277 (Queue: 65554, Visited: 9722)
# 2025-05-12 12:11:13 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/234 (Queue: 65557, Visited: 9722)
# 2025-05-12 12:11:13 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/237 (Queue: 65571, Visited: 9722)
# 2025-05-12 12:11:13 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/310 (Queue: 65585, Visited: 9722)
# 2025-05-12 12:11:13 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/274 (Queue: 65585, Visited: 9722)
# 2025-05-12 12:11:13 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/311 (Queue: 65585, Visited: 9722)
# 2025-05-12 12:11:13 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/170/0 (Queue: 65585, Visited: 9722)
# 2025-05-12 12:11:13 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/checkxt (Queue: 65596, Visited: 9722)
# 2025-05-12 12:11:14 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/198 (Queue: 65596, Visited: 9722)
# ...
# 2025-05-12 12:15:49 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/205 (Queue: 74402, Visited: 9801)
# 2025-05-12 12:15:49 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/318 (Queue: 74402, Visited: 9801)
# 2025-05-12 12:15:49 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/183 (Queue: 74402, Visited: 9801)
# 2025-05-12 12:15:49 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/130 (Queue: 74402, Visited: 9801)
# 2025-05-12 12:15:49 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/203 (Queue: 74402, Visited: 9801)
# 2025-05-12 12:15:49 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/131 (Queue: 74402, Visited: 9801)
# 2025-05-12 12:15:50 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/204 (Queue: 74402, Visited: 9801)
# 2025-05-12 12:15:50 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/132 (Queue: 74402, Visited: 9801)
# 2025-05-12 12:15:50 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/141 (Queue: 74402, Visited: 9801)
# 2025-05-12 12:15:50 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/142 (Queue: 74402, Visited: 9801)
# 2025-05-12 12:15:50 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/317 (Queue: 74402, Visited: 9801)
# 2025-05-12 12:15:50 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/322 (Queue: 74402, Visited: 9801)
# 2025-05-12 12:15:50 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/129 (Queue: 74402, Visited: 9801)
# 2025-05-12 12:15:50 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/133 (Queue: 74402, Visited: 9801)
# 2025-05-12 12:15:50 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/131 (Queue: 74402, Visited: 9801)
# 2025-05-12 12:15:50 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/142 (Queue: 74402, Visited: 9801)
# 2025-05-12 12:15:50 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/141 (Queue: 74402, Visited: 9801)
# 2025-05-12 12:15:50 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/322 (Queue: 74402, Visited: 9801)
# 2025-05-12 12:15:50 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/134 (Queue: 74402, Visited: 9801)
# 2025-05-12 12:15:50 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/130 (Queue: 74402, Visited: 9801)
# 2025-05-12 12:15:50 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/135 (Queue: 74402, Visited: 9801)
# 2025-05-12 12:15:50 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/206 (Queue: 74402, Visited: 9801)
# 2025-05-12 12:15:50 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/133 (Queue: 74402, Visited: 9801)
# 2025-05-12 12:15:50 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/317 (Queue: 74402, Visited: 9801)
# 2025-05-12 12:15:51 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/154/0 (Queue: 74402, Visited: 9801)
# 2025-05-12 12:15:51 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/132 (Queue: 74402, Visited: 9801)
# 2025-05-12 12:15:51 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/275/0 (Queue: 74402, Visited: 9801)
# 2025-05-12 12:15:51 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/273 (Queue: 74402, Visited: 9801)
# 2025-05-12 12:15:51 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/274 (Queue: 74402, Visited: 9801)
# 2025-05-12 12:15:51 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/76/index.php/WebControl/viewpage/190 (Queue: 74402, Visited: 9801)
# 2025-05-12 12:15:51 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/135 (Queue: 74402, Visited: 9801)
# 2025-05-12 12:15:51 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/302/0 (Queue: 74402, Visited: 9801)
# 2025-05-12 12:15:51 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/134 (Queue: 74402, Visited: 9801)
# 2025-05-12 12:15:51 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/76/index.php/WebControl/viewpage/190 (Queue: 74402, Visited: 9801)
# 2025-05-12 12:15:51 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/278 (Queue: 74402, Visited: 9801)
# 2025-05-12 12:15:51 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/206 (Queue: 74402, Visited: 9801)
# 2025-05-12 12:15:51 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/154/0 (Queue: 74404, Visited: 9802)
# 2025-05-12 12:15:51 Worker-4: Đã lưu: uet_vnu_data/education.vnu.edu.vn_index.php_WebControl_listnews_76_index.php_WebControl_viewpage_190.txt
# 2025-05-12 12:15:51 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/275/0 (Queue: 74404, Visited: 9802)
# 2025-05-12 12:15:52 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/150/0 (Queue: 74417, Visited: 9802)
# 2025-05-12 12:15:52 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/148/0 (Queue: 74417, Visited: 9802)
# 2025-05-12 12:15:52 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/302/0 (Queue: 74417, Visited: 9802)
# 2025-05-12 12:15:52 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/213 (Queue: 74416, Visited: 9802)
# Đã lưu nội dung từ https://education.vnu.edu.vn/index.php/WebControl/listnews/76/index.php/WebControl/viewpage/190 vào file.
# 2025-05-12 12:15:52 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/221/0 (Queue: 74428, Visited: 9802)
# 2025-05-12 12:15:52 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/273 (Queue: 74428, Visited: 9802)
# 2025-05-12 12:15:52 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/170/0 (Queue: 74439, Visited: 9802)
# 2025-05-12 12:15:52 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/198 (Queue: 74439, Visited: 9802)
# 2025-05-12 12:15:52 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/278 (Queue: 74439, Visited: 9802)
# 2025-05-12 12:15:52 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/190 (Queue: 74439, Visited: 9802)
# 2025-05-12 12:15:52 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/148/0 (Queue: 74439, Visited: 9802)
# 2025-05-12 12:15:52 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/213 (Queue: 74439, Visited: 9802)
# 2025-05-12 12:15:52 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/221/0 (Queue: 74439, Visited: 9802)
# 2025-05-12 12:15:52 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/277 (Queue: 74453, Visited: 9802)
# 2025-05-12 12:15:53 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/150/0 (Queue: 74453, Visited: 9802)
# 2025-05-12 12:15:53 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/234 (Queue: 74453, Visited: 9802)
# 2025-05-12 12:15:53 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/237 (Queue: 74456, Visited: 9802)
# 2025-05-12 12:15:53 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/198 (Queue: 74456, Visited: 9802)
# 2025-05-12 12:15:53 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/310 (Queue: 74470, Visited: 9802)
# 2025-05-12 12:15:53 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/170/0 (Queue: 74470, Visited: 9802)
# 2025-05-12 12:15:53 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/311 (Queue: 74470, Visited: 9802)
# 2025-05-12 12:15:53 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/274 (Queue: 74470, Visited: 9802)
# 2025-05-12 12:15:53 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/checkxt (Queue: 74481, Visited: 9802)
# 2025-05-12 12:15:53 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/checkxtthpt (Queue: 74481, Visited: 9802)
# 2025-05-12 12:15:53 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/190 (Queue: 74481, Visited: 9802)
# 2025-05-12 12:15:53 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/checkxt2024 (Queue: 74481, Visited: 9802)
# 2025-05-12 12:15:53 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/277 (Queue: 74481, Visited: 9802)
# 2025-05-12 12:15:53 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/checkxtthpt2024 (Queue: 74481, Visited: 9802)
# 2025-05-12 12:15:54 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/237 (Queue: 74481, Visited: 9802)
# 2025-05-12 12:15:54 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/checkxt (Queue: 74481, Visited: 9802)
# 2025-05-12 12:15:54 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/checkxtthpt (Queue: 74481, Visited: 9802)
# 2025-05-12 12:15:54 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/312 (Queue: 74481, Visited: 9802)
# 2025-05-12 12:15:54 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/311 (Queue: 74481, Visited: 9802)
# 2025-05-12 12:15:54 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/checkxt2024 (Queue: 74481, Visited: 9802)
# 2025-05-12 12:15:54 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/310 (Queue: 74481, Visited: 9802)
# 2025-05-12 12:15:54 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/327 (Queue: 74484, Visited: 9802)
# 2025-05-12 12:15:54 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/234 (Queue: 74482, Visited: 9802)
# 2025-05-12 12:15:54 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/searchmark (Queue: 74483, Visited: 9802)
# 2025-05-12 12:15:54 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/313 (Queue: 74483, Visited: 9802)
# 2025-05-12 12:15:54 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/checkpn (Queue: 74484, Visited: 9802)
# 2025-05-12 12:15:54 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/searchmark2 (Queue: 74482, Visited: 9802)
# 2025-05-12 12:15:54 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/330 (Queue: 74484, Visited: 9802)
# 2025-05-12 12:15:54 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/checkxtthpt2024 (Queue: 74484, Visited: 9802)
# 2025-05-12 12:15:54 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewnews/3442 (Queue: 74485, Visited: 9802)
# 2025-05-12 12:15:54 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/312 (Queue: 74485, Visited: 9802)
# 2025-05-12 12:15:54 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewnews/3441 (Queue: 74485, Visited: 9802)
# 2025-05-12 12:15:54 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/313 (Queue: 74485, Visited: 9802)
# 2025-05-12 12:15:55 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/searchmark (Queue: 74485, Visited: 9802)
# 2025-05-12 12:15:55 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/checkpn (Queue: 74485, Visited: 9802)
# 2025-05-12 12:15:55 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewnews/3439 (Queue: 74485, Visited: 9802)
# 2025-05-12 12:15:55 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/327 (Queue: 74485, Visited: 9802)
# 2025-05-12 12:15:55 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewpage/330 (Queue: 74485, Visited: 9802)
# 2025-05-12 12:15:55 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/searchmark2 (Queue: 74485, Visited: 9802)
# 2025-05-12 12:15:55 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewnews/3427 (Queue: 74484, Visited: 9802)
# 2025-05-12 12:15:55 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewnews/3442 (Queue: 74484, Visited: 9802)
# 2025-05-12 12:15:55 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewnews/3440 (Queue: 74485, Visited: 9802)
# 2025-05-12 12:15:55 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewnews/3419 (Queue: 74485, Visited: 9802)
# 2025-05-12 12:15:55 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewnews/3413 (Queue: 74485, Visited: 9802)
# 2025-05-12 12:15:55 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewnews/3410 (Queue: 74484, Visited: 9802)
# 2025-05-12 12:15:55 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewnews/3441 (Queue: 74484, Visited: 9802)
# 2025-05-12 12:15:55 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/15/0 (Queue: 74485, Visited: 9802)
# 2025-05-12 12:15:55 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/16/0 (Queue: 74486, Visited: 9802)
# 2025-05-12 12:15:55 MainThread:
# Đã nhận tín hiệu dừng (Ctrl+C). Báo hiệu cho các worker dừng...
# 2025-05-12 12:15:55 Worker-1: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewnews/3427 (Queue: 74486, Visited: 9802)
# 2025-05-12 12:15:55 Worker-6: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewnews/3439 (Queue: 74486, Visited: 9802)
# 2025-05-12 12:15:55 Worker-3: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/16/0 (Queue: 74486, Visited: 9802)
# 2025-05-12 12:15:55 MainThread: Đợi các worker threads hoàn thành...
# 2025-05-12 12:15:55 Worker-1: Worker-1 is stopping.
# 2025-05-12 12:15:55 Worker-8: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewnews/3440 (Queue: 74488, Visited: 9802)
# 2025-05-12 12:15:55 Worker-4: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewnews/3413 (Queue: 74488, Visited: 9802)
# 2025-05-12 12:15:56 Worker-3: Worker-3 is stopping.
# 2025-05-12 12:15:56 Worker-6: Worker-6 is stopping.
# 2025-05-12 12:15:56 Worker-7: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewnews/3419 (Queue: 74509, Visited: 9802)
# 2025-05-12 12:15:56 Worker-8: Worker-8 is stopping.
# 2025-05-12 12:15:56 Worker-5: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/viewnews/3410 (Queue: 74512, Visited: 9802)
# 2025-05-12 12:15:56 Worker-4: Worker-4 is stopping.
# 2025-05-12 12:15:56 Worker-2: Đang crawl: https://education.vnu.edu.vn/index.php/WebControl/listnews/15/0 (Queue: 74513, Visited: 9802)
# 2025-05-12 12:15:56 Worker-7: Worker-7 is stopping.
# 2025-05-12 12:15:56 Worker-5: Worker-5 is stopping.
# 2025-05-12 12:15:56 Worker-2: Worker-2 is stopping.
# 2025-05-12 12:15:56 MainThread: Tất cả worker threads đã dừng (hoặc timeout).
# 2025-05-12 12:15:56 MainThread: Đang lưu trạng thái vào crawl_state_2.json...
# 2025-05-12 12:15:56 MainThread: Đã lưu trạng thái: Queue=74537, Visited=9802
# 2025-05-12 12:15:56 MainThread: Tổng số URL đã xử lý (ước tính): 2973
# 2025-05-12 12:15:56 MainThread: Chương trình kết thúc.
